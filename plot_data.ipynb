# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_dirs = [r"C:\Geotech_Research\Linux_Testing\dry_oedometer\dry_oedometer_v1_1\dry_oedometer_v1_1.PAR_005",
             r"C:\Geotech_Research\Linux_Testing\dry_oedometer\dry_oedometer_sln_v1_1\dry_oedometer_sln_v1_1.PAR_005",
             r"C:\Geotech_Research\Linux_Testing\dry_oedometer\dry_oedometer_external_sln_v1_1\dry_oedometer_external_sln_v1_1.PAR_005"
]

colors = ["red", "blue", "green"]
names = ["make", "sln", "external_sln"]

# Plot the data
for i, file in enumerate(file_dirs):
    # Read the data
    df = pd.read_csv(file, delim_whitespace=True)

    if i == 2:
        plt.plot(df["Time"], df["Uy"], label = names[i], linestyle = "dashed")
    else:
        # Plot the data
        plt.plot(df["Time"], df["Uy"], label = names[i])
plt.legend()
